# %%
import numpy
import math

# %%
#expr(1)
int(sum(list(range(2**25+1))))

# %%
#expr(2)
int(math.factorial(1000))
# Out:
# ...

# %%
#expr(3)
pass
# Out:
# bn,df
# 'fd,nb'

# %%
#expr(4)
list(numpy.setdiff1d(a,b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e46eba1adf6d> in <module>
#       1 #expr(4)
#       2 import numpy
# ----> 3 list(numpy.setdiff1d(a,b))
#
# NameError: name 'a' is not defined

# %%
#expr(5)
pass
# Out:
# 562949970198528

# %%
#expr(6)
pass

# %%
#expr(7)
''.join(reversed(input()))
# Out:
# hflk
# 'klfh'

# %%
#expr(8)
pass

# %%
#expr(9)
'{0:.20f}'.format(math.pi)
# Out:
# '3.14159265358979311600'

# %%
from test_.suite import run_tests
run_tests("one-liners.ipynb")
